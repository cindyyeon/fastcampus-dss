# %% [markdown]
# ### 7주차 과제

# %% [markdown]
# - (회귀분석_09. 결측 데이터 처리)아래의 명령어는 scikit-learn패키지를 이용해, 결측 데이터를 '다른 데이터에서 대표값을 찾아 채우는 방법'으로 처리하는 과정입니다.
# - 대표값으로 최빈값을 사용할 때, 비어진 명령어('###')를 채워주세요.

# %%
import seaborn as sns
from sklearn.impute import SimpleImputer
import pandas as pd

# %%
df = sns.load_dataset('titanic')
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
# 여기에 코드를 작성해주세요. (20점)
imputer_mode = SimpleImputer(strategy='most_frequent')
df = pd.DataFrame(imputer_mode.fit_transform(df), columns=df.columns)
df.tail()
# Out:
#     survived pclass     sex age sibsp parch   fare embarked   class    who  \
# 886        0      2    male  27     0     0     13        S  Second    man
# 887        1      1  female  19     0     0     30        S   First  woman
# 888        0      3  female  24     1     2  23.45        S   Third  woman
# 889        1      1    male  26     0     0     30        C   First    man
# 890        0      3    male  32     0     0   7.75        Q   Third    man
#
#     adult_male deck  embark_town alive  alone
# 886       True    C  Southampton    no   True
# 887      False    B  Southampton   yes   True
# 888      False    C  Southampton    no  False
# 889       True    C    Cherbourg   yes   True
# 890       True    C   Queenstown    no   True

# %% [markdown]
# ### 7주차 퀴즈

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
titanic_processed = titanic.dropna()

# %%
titanic_processed.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
